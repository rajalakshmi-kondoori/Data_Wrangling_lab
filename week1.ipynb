# %% [markdown]
# <a href="https://colab.research.google.com/github/rajalakshmi-kondoori/Data_Wrangling_lab/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/weekday.csv')
df
# Out:
#         Name Abbreviation  Numeric  Numeric-2
# 0     Monday         Mon.        1          1
# 1    Tuesday         Tue.        2          2
# 2  Wednesday         Wed.        3          3
# 3   Thursday         Thu.        4          4
# 4     Friday         Fri.        5          5
# 5   Saturday         Sat.        6          6
# 6     Sunday         Sun.        7          7

# %%
df.head()
# Out:
#         Name Abbreviation  Numeric  Numeric-2
# 0     Monday         Mon.        1          1
# 1    Tuesday         Tue.        2          2
# 2  Wednesday         Wed.        3          3
# 3   Thursday         Thu.        4          4
# 4     Friday         Fri.        5          5

# %%
df.head(3)
# Out:
#         Name Abbreviation  Numeric  Numeric-2
# 0     Monday         Mon.        1          1
# 1    Tuesday         Tue.        2          2
# 2  Wednesday         Wed.        3          3

# %%
df.tail()
# Out:
#         Name Abbreviation  Numeric  Numeric-2
# 2  Wednesday         Wed.        3          3
# 3   Thursday         Thu.        4          4
# 4     Friday         Fri.        5          5
# 5   Saturday         Sat.        6          6
# 6     Sunday         Sun.        7          7

# %%
df.sample(4)
# Out:
#         Name Abbreviation  Numeric  Numeric-2
# 8  September        Sept.        9          9
# 3      April         Apr.        4          4
# 4        May          May        5          5
# 6       July         July        7          7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          12 non-null     object
#  1   Abbreviation  12 non-null     object
#  2   Numeric       12 non-null     int64
#  3   Numeric-2     12 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 512.0+ bytes

# %%
df.dtypes
# Out:
# Name            object
# Abbreviation    object
# Numeric          int64
# Numeric-2        int64
# dtype: object

# %%
df.shape
# Out:
# (12, 4)

# %%
df.size
# Out:
# 48

# %%
df.ndim
# Out:
# 2

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          Name Abbreviation  Numeric  Numeric-2
# 0     January         Jan.        1          1
# 1    Feburary         Feb.        2          2
# 2       March         Mar.        3          3
# 3       April         Apr.        4          4
# 4         May          May        5          5
# 5        June         June        6          6
# 6        July         July        7          7
# 7      August         Aug.        8          8
# 8   September        Sept.        9          9
# 9     October         Oct.       10         10
# 10   November         Nov.       11         11
# 11   December         Dec.       12         12>

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of          Name Abbreviation  Numeric  Numeric-2
# 0     January         Jan.        1          1
# 1    Feburary         Feb.        2          2
# 2       March         Mar.        3          3
# 3       April         Apr.        4          4
# 4         May          May        5          5
# 5        June         June        6          6
# 6        July         July        7          7
# 7      August         Aug.        8          8
# 8   September        Sept.        9          9
# 9     October         Oct.       10         10
# 10   November         Nov.       11         11
# 11   December         Dec.       12         12>

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of          Name Abbreviation  Numeric  Numeric-2
# 0     January         Jan.        1          1
# 1    Feburary         Feb.        2          2
# 2       March         Mar.        3          3
# 3       April         Apr.        4          4
# 4         May          May        5          5
# 5        June         June        6          6
# 6        July         July        7          7
# 7      August         Aug.        8          8
# 8   September        Sept.        9          9
# 9     October         Oct.       10         10
# 10   November         Nov.       11         11
# 11   December         Dec.       12         12>

# %%
df.isna
# Out:
# <bound method DataFrame.isna of          Name Abbreviation  Numeric  Numeric-2
# 0     January         Jan.        1          1
# 1    Feburary         Feb.        2          2
# 2       March         Mar.        3          3
# 3       April         Apr.        4          4
# 4         May          May        5          5
# 5        June         June        6          6
# 6        July         July        7          7
# 7      August         Aug.        8          8
# 8   September        Sept.        9          9
# 9     October         Oct.       10         10
# 10   November         Nov.       11         11
# 11   December         Dec.       12         12>

# %%
df.clip
# Out:
# <bound method NDFrame.clip of          Name Abbreviation  Numeric  Numeric-2
# 0     January         Jan.        1          1
# 1    Feburary         Feb.        2          2
# 2       March         Mar.        3          3
# 3       April         Apr.        4          4
# 4         May          May        5          5
# 5        June         June        6          6
# 6        July         July        7          7
# 7      August         Aug.        8          8
# 8   September        Sept.        9          9
# 9     October         Oct.       10         10
# 10   November         Nov.       11         11
# 11   December         Dec.       12         12>

# %%
df.columns
# Out:
# Index(['Name', 'Abbreviation', 'Numeric', 'Numeric-2'], dtype='object')

# %%
df.iloc

# %%
df.copy
# Out:
# <bound method NDFrame.copy of          Name Abbreviation  Numeric  Numeric-2
# 0     January         Jan.        1          1
# 1    Feburary         Feb.        2          2
# 2       March         Mar.        3          3
# 3       April         Apr.        4          4
# 4         May          May        5          5
# 5        June         June        6          6
# 6        July         July        7          7
# 7      August         Aug.        8          8
# 8   September        Sept.        9          9
# 9     October         Oct.       10         10
# 10   November         Nov.       11         11
# 11   December         Dec.       12         12>

# %%
df.median
# Out:
# <bound method DataFrame.median of          Name Abbreviation  Numeric  Numeric-2
# 0     January         Jan.        1          1
# 1    Feburary         Feb.        2          2
# 2       March         Mar.        3          3
# 3       April         Apr.        4          4
# 4         May          May        5          5
# 5        June         June        6          6
# 6        July         July        7          7
# 7      August         Aug.        8          8
# 8   September        Sept.        9          9
# 9     October         Oct.       10         10
# 10   November         Nov.       11         11
# 11   December         Dec.       12         12>
